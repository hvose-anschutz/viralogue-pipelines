# %% [markdown]
# # SINGLE CELL ANALYSIS FOR DIET PAPER
#
# The data in this notebook will be used to generate all analyses for the diet paper

# %%
# STEP 1: Imports
import re
import os
import pprint
import warnings
import scanpy as sc
import anndata as ad
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import gprofiler
import gseapy as gp
from gseapy import Biomart

warnings.filterwarnings('ignore')
sns.set_style("ticks")
